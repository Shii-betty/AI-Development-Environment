# %%
import sys

print("Hello World!")
print("Python version:", sys.version)
# Out:
# Hello World!
# Python version: 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]

# %%
import platform

print("Operating System:", platform.system())
print("Python Version:", platform.python_version())
print("Development Environment: Google Colab")
# Out:
# Operating System: Linux
# Python Version: 3.13.15
# Development Environment: Google Colab

# %%
# Simple Hello World Application

def hello_world():
    return "Hello World! My AI development environment is working."

print(hello_world())
# Out:
# Hello World! My AI development environment is working.

# %%
# %%writefile app.py

def hello_world():
    return "Hello World! My AI development environment is working."

if __name__ == "__main__":
    print(hello_world())
# Out:
# Writing app.py

# %%
# !python app.py
# Out:
# Hello World! My AI development environment is working.

# %%
# Simple Hello World Application

def hello_world():
    return "Hello World! My AI development environment is working."

print(hello_world())
# Out:
# Hello World! My AI development environment is working.

# %%
# %%writefile app.py

def hello_world():
    return "Hello World! My AI development environment is working."

if __name__ == "__main__":
    print(hello_world())
# Out:
# Overwriting app.py

# %%
# !python app.py
# Out:
# Hello World! My AI development environment is working.

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'app.py', 'sample_data']

# %%
from google.colab import files

files.download('app.py')
